# %%
import pandas as pd
import numpy as np

# %%
#lets load our data as it is in csv form so we can read data as 
data = pd.read_csv('Transactions.csv')
data.shape
# Out:
# (1256400, 46)

# %%
# roi = data

# cleaned_roi = roi.dropna()
# # roi.isnull().sum()
# # cleaned_roi.isnull().sum()
# # cleaned_roi.shape
# # # Convert 'instance_date' to datetime format
# cleaned_roi['instance_date'] = pd.to_datetime(cleaned_roi['instance_date'])
# # cleaned_roi.sort_values(['instance_date'])
# # data = data.loc[( data['instance_date'] >= '2010-01-01')]
# # data = data.loc[( data['instance_date'] < '2024-01-01')]
# # cleaned_roi

# # # Extract year from 'instance_date'
# # df['year'] = df['instance_date'].dt.year

# # Group by 'year' and 'property_usage_en', then sum 'actual_worth'
# # yearly_sum3 = cleaned_roi.groupby(['', 'rent_value'])['actual_worth'].sum().reset_index()

# # # Create pivot table with 'year' as index, 'property_usage_en' as columns, and sum of 'actual_worth' as values
# # pivot_table2 = yearly_sum2.pivot(index='year', columns='area_name_en', values='actual_worth')

# # # Fill NaN values with 0 (optional)
# # # pivot_table['Hospitality'] = pivot_table['Hospitality']/1e6
# # # Display the pivot table
# # # pivot_table = pivot_table.drop('Residential/Commercial')
# # pivot_table2 = pivot_table2.reset_index()
# # pivot_table2
# # Get distinct values from the 'property_usage_en' column
# # distinct_values = cleaned_roi['rooms_en'].unique()

# # # Convert to a list if needed
# # distinct_values_list = distinct_values.tolist()

# # print(distinct_values_list)
# # cleaned_roi.columns

# %%
data['instance_date'] = pd.to_datetime(data['instance_date'], errors='coerce') 
data.sort_values(by=['instance_date'], inplace=True)
data = data.loc[( data['instance_date'] >= '2012-01-01')]
data = data.loc[( data['instance_date'] < '2024-01-01')]
data
# Out:
# C:\Users\dk381\AppData\Local\Temp\ipykernel_9808\2665198124.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['instance_date'] = pd.to_datetime(data['instance_date'], errors='coerce')
#            transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 170904    1-110-2011-2950           110               1        مبايعات
# 917182       2-13-2012-20            13               2           رهون
# 864672        1-11-2012-8            11               1        مبايعات
# 376811    1-11-2011-20549            11               1        مبايعات
# 958941       1-11-2012-23            11               1        مبايعات
# ...                   ...           ...             ...            ...
# 1130633  1-102-2023-69437           102               1        مبايعات
# 912770   1-102-2023-69385           102               1        مبايعات
# 553094   1-102-2023-69442           102               1        مبايعات
# 1074461     3-9-2023-6708             9               3           هبات
# 1011835  1-102-2023-69439           102               1        مبايعات
#
#         trans_group_en           procedure_name_ar          procedure_name_en  \
# 170904           Sales  تسجيل إيجارة تنتهى بالتملك  Lease to Own Registration
# 917182       Mortgages                   تسجيل رهن      Mortgage Registration
# 864672           Sales                         بيع                       Sell
# 376811           Sales                         بيع                       Sell
# 958941           Sales                         بيع                       Sell
# ...                ...                         ...                        ...
# 1130633          Sales           بيع - تسجيل مبدئى    Sell - Pre registration
# 912770           Sales           بيع - تسجيل مبدئى    Sell - Pre registration
# 553094           Sales           بيع - تسجيل مبدئى    Sell - Pre registration
# 1074461          Gifts                         هبه                      Grant
# 1011835          Sales           بيع - تسجيل مبدئى    Sell - Pre registration
#
#         instance_date  property_type_id property_type_ar  ... rooms_en  \
# 170904     2012-01-02                 1              أرض  ...      NaN
# 917182     2012-01-02                 4             فيلا  ...      NaN
# 864672     2012-01-02                 3             وحدة  ...   Studio
# 376811     2012-01-02                 4             فيلا  ...    3 B/R
# 958941     2012-01-02                 3             وحدة  ...      NaN
# ...               ...               ...              ...  ...      ...
# 1130633    2023-12-29                 3             وحدة  ...    2 B/R
# 912770     2023-12-29                 3             وحدة  ...    1 B/R
# 553094     2023-12-29                 3             وحدة  ...    1 B/R
# 1074461    2023-12-29                 3             وحدة  ...    1 B/R
# 1011835    2023-12-29                 3             وحدة  ...    1 B/R
#
#          has_parking procedure_area actual_worth meter_sale_price rent_value  \
# 170904             0         540.14    3264800.0          6044.36        NaN
# 917182             0         674.48    2640000.0          3914.13        NaN
# 864672             1          48.10     345000.0          7172.56        NaN
# 376811             0         135.20    2200000.0         16272.19        NaN
# 958941             0          67.00     374584.0          5590.81        NaN
# ...              ...            ...          ...              ...        ...
# 1130633            1         107.64    2270888.0         21097.06        NaN
# 912770             1          57.44    1228500.0         21387.53        NaN
# 553094             1          69.93     917959.0         13126.83        NaN
# 1074461            1          66.10    1763668.0         26681.82        NaN
# 1011835            1          67.75    1613888.0         23821.23        NaN
#
#          meter_rent_price no_of_parties_role_1 no_of_parties_role_2  \
# 170904                NaN                  2.0                  2.0
# 917182                NaN                  1.0                  1.0
# 864672                NaN                  1.0                  1.0
# 376811                NaN                  1.0                  1.0
# 958941                NaN                  1.0                  1.0
# ...                   ...                  ...                  ...
# 1130633               NaN                  1.0                  2.0
# 912770                NaN                  1.0                  1.0
# 553094                NaN                  1.0                  1.0
# 1074461               NaN                  1.0                  1.0
# 1011835               NaN                  1.0                  1.0
#
#          no_of_parties_role_3
# 170904                    2.0
# 917182                    0.0
# 864672                    0.0
# 376811                    0.0
# 958941                    0.0
# ...                       ...
# 1130633                   0.0
# 912770                    0.0
# 553094                    0.0
# 1074461                   0.0
# 1011835                   0.0
#
# [899613 rows x 46 columns]

# %%
data.shape
# Out:
# (899613, 46)

# %%
# Set the date column as the index
# df.set_index('instance_date', inplace=True)
# df=data.set_index('instance_date')

# # Resample the data yearly and sum the 'actual_worth' column
# df_yearly_sum = df_clean['actual_worth'].resample('Y').sum()

# # If you want the result as a DataFrame, reset the index
# df_yearly_sum = df_yearly_sum.reset_index()

# df_yearly_sum['actual_worth'] = df_yearly_sum['actual_worth']/1e9
# # Display the yearly summed data
# df_yearly_sum
# data['instance_date'] = pd.to_datetime(data['instance_date'])
# # Group by the year and sum the 'Transaction' column
# yearly_sum['Year'] = data['instance_date'].dt.year  # Extract year from the 'Date' column
# yearly_sum = yearly_sum.set_index('Year')
# yearly_sum = data.groupby('Year')['actual_worth'].sum()

# yearly_sum.reset_index()
# # print("\nYearly Sum of Transactions:")
# yearly_sum



# data['instance_date'] = pd.to_datetime(data['instance_date'])
# data['Year'] = data['instance_date'].dt.year  # Extract year from the 'Date' column
# yearly_sum = data.groupby('Year')['actual_worth'].sum().reset_index()
# yearly_sum['actual_worth'] = yearly_sum['actual_worth']/1e9
# yearly_sum['actual_worth'] = yearly_sum['actual_worth'].round(2)
# yearly_sum['Year'] = yearly_sum['Year'].astype(int)
# print("\nYearly Sum of Transactions:")
# print(yearly_sum[27:51])

# %%
# merged_df = pd.merge(yearly_sum, eco_df, on='Year')
columns_to_drop=["trans_group_ar","procedure_name_ar","property_type_ar","property_sub_type_ar","property_usage_ar","reg_type_ar","area_name_ar",
                 "building_name_ar","project_name_ar","master_project_ar","nearest_landmark_ar","nearest_metro_ar","nearest_mall_ar","rooms_ar",
                 ]
df = data.drop(columns=columns_to_drop)
df = df.dropna(subset=['instance_date'])
df.isna().sum()
df.shape
# df.columns
# Out:
# (899613, 32)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from scipy.sparse import csr_matrix

# Define categorical and numerical features
categorical_features = ['procedure_id', 'trans_group_id', 'trans_group_en', 'procedure_name_en', 
                        'property_type_id', 'property_type_en', 'property_usage_en', 
                        'reg_type_id', 'reg_type_en', 'area_id', 'area_name_en', 'has_parking']
numerical_features = ['procedure_area', 'meter_sale_price']

# Preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', MinMaxScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)])

# Apply preprocessing
X = df.drop('actual_worth', axis=1)
y = df['actual_worth'].values.reshape(-1, 1)

X_preprocessed = preprocessor.fit_transform(X)
y_scaler = MinMaxScaler()
y_scaled = y_scaler.fit_transform(y)

# Convert sparse matrix to dense matrix if necessary
if isinstance(X_preprocessed, csr_matrix):
    X_preprocessed = X_preprocessed.toarray()

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y_scaled, test_size=0.2, random_state=42)

# Reshape for LSTM
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(1, X_train.shape[2])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))

# Make predictions
predictions = model.predict(X_test)
predictions = y_scaler.inverse_transform(predictions)

# Plot the results
import matplotlib.pyplot as plt

plt.plot(y_scaler.inverse_transform(y_test), label='Actual Value')
plt.plot(predictions, label='Predicted Value')
plt.legend()
plt.show()
# Out:
# Epoch 1/5
# 22491/22491 [==============================] - 216s 9ms/step - loss: 1.9427e-05 - val_loss: 4.3014e-05
# Epoch 2/5
# 22491/22491 [==============================] - 202s 9ms/step - loss: 1.8560e-05 - val_loss: 3.8323e-05
# Epoch 3/5
# 22491/22491 [==============================] - 201s 9ms/step - loss: 1.7990e-05 - val_loss: 3.7523e-05
# Epoch 4/5
# 22491/22491 [==============================] - 201s 9ms/step - loss: 1.7396e-05 - val_loss: 4.0186e-05
# Epoch 5/5
# 22491/22491 [==============================] - 202s 9ms/step - loss: 1.6580e-05 - val_loss: 3.5547e-05
# 5623/5623 [==============================] - 23s 4ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data (replace with your actual data)
# Historical data
historical_years = np.arange(2010, 2024)  # 2010 to 2023
# Assuming y_test has been scaled and needs inverse transformation
historical_actual_values = y_scaler.inverse_transform(y_test[:len(historical_years)]).flatten()

# Generate feature data for future years
# Dummy feature generation for future years (replace with actual feature logic)
def create_future_features(years):
    # Placeholder: replace with real feature data generation
    future_features = np.zeros((len(years), X_preprocessed.shape[1]))
    return future_features

X_future = create_future_features(np.arange(2024, 2031))

# Reshape future features for LSTM
X_future = X_future.reshape((X_future.shape[0], 1, X_future.shape[1]))

# Predict future values
future_predictions = model.predict(X_future)
future_predictions = y_scaler.inverse_transform(future_predictions).flatten()

# Future years
future_years = np.arange(2024, 2031)  # 2024 to 2030

# Combine historical and future data for plotting
years = np.concatenate([historical_years, future_years])
values = np.concatenate([historical_actual_values, future_predictions])

# Plot the actual and predicted values
plt.figure(figsize=(12, 6))
plt.plot(historical_years, historical_actual_values, label='Actual Value', color='blue', marker='o')
plt.plot(future_years, future_predictions, label='Predicted Value', color='red', linestyle='--')
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 41ms/step

# %%
# lets see the what numbers of rows and columns we have in our data
# we can do this with two method len() and shape[], len() is fast but 
# when we need row and column both then we can we shape(), see how
total_rows = data.shape
total_rows = data.shape[0]
total_columns = data.shape[1]
f'Total_number_of_rows = {total_rows} and Total_number_of_colums = {total_columns}'
# Out:
# 'Total_number_of_rows = 899613 and Total_number_of_colums = 46'

# %%
# we know no. of rows and columns as well data structures so we will delete unnecessary columns and rows see how
# we can do this using any one method belows
# data = data.drop(labels='column_name', axis = 1)
# data = data.drop(labels=['column_name'], axis = 1)



# columns_to_drop=["trans_group_ar","procedure_name_ar","property_type_ar","property_sub_type_ar","property_usage_ar","reg_type_ar","area_name_ar",
#                  "building_name_ar","project_name_ar","master_project_ar","nearest_landmark_ar","nearest_metro_ar","nearest_mall_ar","rooms_ar",
#                  "meter_rent_price","rent_value","property_sub_type_id","property_sub_type_en","building_name_en","project_number","project_name_en",
#                  "nearest_landmark_en","nearest_metro_en","nearest_mall_en","no_of_parties_role_1","no_of_parties_role_2","no_of_parties_role_3",
#                 "master_project_en","rooms_en"]
# df = data.drop(columns=columns_to_drop)
# df = df.dropna(subset=['instance_date'])

# %%
# lets check the data and we see before we have 46 columns but now we have delete  so we have  columns
# df.info()

# %%
# Now lets see rows we have all together 1256400 rows but we dont need all these so lets cleans
# here in this real estate data analysis we need only data from  2014 till now so see how we will get this
# Our strategy should be first we short data based on time and then filtered the required data
# so to sort data with date first we need to check date datatypes see how

type(df.instance_date[0])

# But the types of instance_date is str so we need to convert into datetime data and if we encounter any error regarding data
# not in ISO format or anythings else then we use erros='coerce' it just convert unmatching date into NaT means you are getting
# error because of missing values i.e NaT represent missing values
# Use to_datetime() method as it is pandas method so we use pd.to_datetime
df['instance_date'] = pd.to_datetime(df['instance_date'],errors='coerce') 

# Now if you will check data types you will get <class 'pandas._libs.tslibs.timestamps.Timestamp'> 
# now pandas will take care of date we only need to specify format
# Now lets sort data we will use in-built method i.e sort_values see how
df.sort_values(by=['instance_date'], inplace=True)

# i use inplace means it will sort data with date in place
# Now we will filtered required data from 2014 till now see how
df = df.loc[(df['instance_date'] > '2011-12-31')]
df = df.loc[(df['instance_date'] < '2024-01-01')]
df.shape
# Out:
# (899613, 32)

# %%
# Now lets Clean data we will isnull(), notnull(), dropna(), fillna(), replace() ,interpolate() 
# for detecting, removing and replacing null values in pandas dataframe.
# use either pandas .isna() .isnull() methods or numpy .isnan() function

df.shape
# Out:
# (899613, 32)

# %%
# plt.figure(figsize=(12, 6))
# plt.scatter(df['instance_date'], df['actual_worth'], s=150, alpha=0.5, c='blue', linewidth=2)
# plt.xlabel('Year')
# plt.ylabel('Sales (in Billion)')
# plt.title('Yearly Sales Data (Bubble Chart)')
# plt.grid(True)
# plt.show()

# import seaborn as sns

# df['instance_date'] = pd.to_datetime(df['instance_date'])

# # Create a DataFrame for heatmap
# df['Year'] = df['instance_date'].dt.year
# heatmap_data = df.set_index('Year').T
# plt.figure(figsize=(12, 6))
# sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='g')
# plt.title('Sales Heatmap Over Time')
# plt.show()

# %%
df['instance_date'] = pd.to_datetime(df['instance_date'])
df.shape
# Out:
# (899613, 32)

# %%
# Set the date column as the index
# df.set_index('instance_date', inplace=True)
df_clean=df.set_index('instance_date')

# # Resample the data yearly and sum the 'actual_worth' column
df_yearly_sum = df_clean['actual_worth'].resample('YE').sum()

# # # If you want the result as a DataFrame, reset the index
df_yearly_sum = df_yearly_sum.reset_index()



df_yearly_sum['Growth_Rate'] = df_yearly_sum['actual_worth'].pct_change() * 100
# df_yearly_sum['instance_date'] = df_yearly_sum.loc[(df_yearly_sum['instance_date'] > '2012-12-31')]
df_yearly_sum['instance_date'] = df_yearly_sum['instance_date'].dt.year
# # # # Display the yearly summed data
df_yearly_sum
# Out:
#     instance_date  actual_worth  Growth_Rate
# 0            2012  1.868571e+11          NaN
# 1            2013  2.662973e+11    42.513877
# 2            2014  2.535445e+11    -4.788952
# 3            2015  2.610750e+11     2.970095
# 4            2016  2.648872e+11     1.460184
# 5            2017  2.691982e+11     1.627504
# 6            2018  2.164877e+11   -19.580560
# 7            2019  2.143377e+11    -0.993142
# 8            2020  1.705949e+11   -20.408348
# 9            2021  2.936525e+11    72.134380
# 10           2022  5.202004e+11    77.148304
# 11           2023  6.337713e+11    21.832155

# %%
import matplotlib.pyplot as plt

# Convert Actual Worth to billions for display
df_yearly_sum['Actual_Worth_Billion'] = df_yearly_sum['actual_worth'] / 1e9  # Convert to billions

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plotting Actual Worth as Bar Chart
color = 'tab:blue'
ax1.set_xlabel('Year')
# ax1.set_xticklabels(df_yearly_sum['instance_date'])
ax1.set_ylabel('Market Volume (Actual Worth in Billion)', color=color)
bars = ax1.bar(df_yearly_sum['instance_date'], df_yearly_sum['Actual_Worth_Billion'], color=color, alpha=1, label='Market Volume')
ax1.tick_params(axis='y', labelcolor=color)

# Annotate bars with Actual Worth values
for bar in bars:
    height = bar.get_height()
    ax1.annotate(f'{height:.2f}B',
                 xy=(bar.get_x() + bar.get_width() / 2, height),
                 xytext=(0, 3),  # 3 points vertical offset
                 textcoords='offset points',
                 ha='center', va='bottom')

# Important Figure
    
# # Add titles and legends
fig.suptitle('UAE Real Estate Market Volume in Billions (2012-2023)')
ax1.legend(loc='upper left')
# ax2.legend(loc='upper right')

# # Show plot
plt.show()

# %%
# Convert Actual Worth to billions for display
df_yearly_sum['Actual_Worth_Billion'] = df_yearly_sum['actual_worth'] / 1e9  # Convert to billions

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

ax2 = ax1
color = 'tab:pink'
ax2.set_ylabel('Growth Rate (%)', color=color)
ax2.set_xlabel('Year', color=color)
line = ax2.plot(df_yearly_sum['instance_date'], df_yearly_sum['Growth_Rate'], color=color, marker='o', label='Growth Rate')
ax2.tick_params(axis='y', labelcolor=color)

# Annotate line with Growth Rate values
for x, y in zip(df_yearly_sum['instance_date'], df_yearly_sum['Growth_Rate']):
    ax2.annotate(f'{y:.2f}%',
                 xy=(x, y),
                 xytext=(0, 5),  # 5 points vertical offset
                 textcoords='offset points',
                 ha='center', va='bottom')

# Important Figure
    
# # Add titles and legends
fig.suptitle('UAE Real Estate Market Growth Rate')
ax2.legend(loc='upper left')
# ax2.legend(loc='upper right')

# # Show plot
plt.show()

# %%
# Convert 'instance_date' to datetime format

df['instance_date'] = pd.to_datetime(df['instance_date'])

# Extract year from 'instance_date'
df['year'] = df['instance_date'].dt.year

# Group by 'year' and 'property_usage_en', then sum 'actual_worth'
df_yearly_sum2 = df.groupby(['year', 'property_usage_en'])['actual_worth'].sum().reset_index()

# Create pivot table with 'year' as index, 'property_usage_en' as columns, and sum of 'actual_worth' as values
pivot_table1 = df_yearly_sum2.pivot(index='year', columns='property_usage_en', values='actual_worth')

pivot_table1 = pivot_table1.reset_index()
pivot_table1 = pivot_table1.drop(columns = ['Residential / Commercial'])
pivot_table1['actual_worth'] = df_yearly_sum['actual_worth']
pivot_table1
# Out:
# property_usage_en  year  Agricultural    Commercial  Hospitality   \
# 0                  2012  4.526142e+08  8.343445e+10  2.416291e+09
# 1                  2013  6.932393e+08  1.246630e+11  8.374688e+09
# 2                  2014  6.924681e+08  9.930736e+10  7.399922e+09
# 3                  2015  6.617405e+08  1.140711e+11  3.952331e+09
# 4                  2016  6.797460e+08  1.160385e+11  3.826304e+09
# 5                  2017  1.100119e+09  9.726323e+10  5.909154e+09
# 6                  2018  1.020970e+09  8.160257e+10  5.612487e+09
# 7                  2019  2.900236e+08  7.153100e+10  5.051677e+09
# 8                  2020  5.994350e+08  5.955588e+10  5.670845e+09
# 9                  2021  5.989417e+08  8.701144e+10  8.424432e+09
# 10                 2022  7.144937e+08  1.368331e+11  1.148925e+10
# 11                 2023  5.323207e+08  1.843434e+11  1.235269e+10
#
# property_usage_en    Industrial     Multi-Use         Other   Residential  \
# 0                  1.293200e+09  1.380434e+09  2.060837e+10  7.724450e+10
# 1                  2.455631e+09  1.098616e+09  8.986659e+09  1.199266e+11
# 2                  4.779734e+09  2.738780e+09  1.415638e+10  1.241717e+11
# 3                  4.381529e+09  1.993984e+09  1.814546e+10  1.176062e+11
# 4                  7.786490e+09  3.611764e+09  2.520918e+10  1.075999e+11
# 5                  9.891001e+09  7.406065e+09  3.042872e+10  1.170130e+11
# 6                  5.057218e+09  1.037692e+10  1.557677e+10  9.706880e+10
# 7                  5.402888e+09  5.055376e+09  2.182771e+10  1.050777e+11
# 8                  4.409836e+09  2.928757e+09  1.389261e+10  8.347534e+10
# 9                  7.451585e+09  3.648514e+09  2.099767e+10  1.653173e+11
# 10                 4.898012e+09  1.169043e+10  5.115660e+10  3.030557e+11
# 11                 9.720885e+09  7.798570e+09  3.071223e+10  3.879539e+11
#
# property_usage_en      Storage  actual_worth
# 0                    7251465.0  1.868571e+11
# 1                   98975107.0  2.662973e+11
# 2                  232124863.0  2.535445e+11
# 3                   98358149.0  2.610750e+11
# 4                  117297033.0  2.648872e+11
# 5                  186982750.0  2.691982e+11
# 6                  171965000.0  2.164877e+11
# 7                  101305116.0  2.143377e+11
# 8                   62191823.0  1.705949e+11
# 9                  202574352.0  2.936525e+11
# 10                 110740000.0  5.202004e+11
# 11                 121963672.0  6.337713e+11

# %%
# Set the year as the index
pivot_table1.set_index('year', inplace=True)

# Plot stacked bar graph
pivot_table1.plot(kind='bar', stacked=True, figsize=(12, 6))

# Add title and labels
plt.title('Investment by Sector for 2023 and 2024')
plt.xlabel('Year')
plt.ylabel('Investment Value')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert values to millions
pivot_table1[['Agricultural', 'Commercial', 'Hospitality ', 'Industrial', 
             'Multi-Use', 'Other', 'Residential', 'Storage', 'actual_worth']] /= 1e6

# Recalculate Total_Sum and Difference
pivot_table1['Total_Sum'] = pivot_table1[['Agricultural', 'Commercial', 'Hospitality ', 'Industrial', 
                                          'Multi-Use', 'Other', 'Residential', 'Storage']].sum(axis=1)
pivot_table1['Difference'] = pivot_table1['actual_worth'] - pivot_table1['Total_Sum']

# Custom dark colors for each category
colors = ['#2c3e50', '#8e44ad', '#c0392b', '#d35400', '#27ae60', '#2980b9', '#f39c12', '#16a085']

plt.figure(figsize=(14, 8))

# Stacked bar plot with darker colors
pivot_table1.set_index('year')[['Agricultural', 'Commercial', 'Hospitality ', 'Industrial', 
                                'Multi-Use', 'Other', 'Residential', 'Storage']].plot(kind='bar', 
                                stacked=True, color=colors, figsize=(14, 8))

# Plot actual_worth
plt.plot(pivot_table1['year'], pivot_table1['actual_worth'], color='black', marker='o', linestyle='--', label='Actual Worth', linewidth=2)

# Customizing plot
plt.title('UAE Real Estate Sales by Property Usage (in Millions)')
plt.xlabel('Year')
plt.ylabel('Property Sales Volume (in Millions)')

# Define y-axis ticks to fit the data range, in millions
max_value = pivot_table1['actual_worth'].max()
y_ticks = np.linspace(0, max_value, num=10)  # Adjust num for more or fewer ticks
plt.yticks(y_ticks, labels=[f'{int(val):,}' for val in y_ticks])

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()

# Remove gridlines
plt.grid(False)

# Show plot
plt.show()

# %%
# Convert 'instance_date' to datetime format

df['instance_date'] = pd.to_datetime(df['instance_date'])

# Extract year from 'instance_date'
df['year'] = df['instance_date'].dt.year

# Group by 'year' and 'property_usage_en', then sum 'actual_worth'
df_yearly_sum3 = df.groupby(['year', 'property_type_en'])['actual_worth'].sum().reset_index()

# Create pivot table with 'year' as index, 'property_usage_en' as columns, and sum of 'actual_worth' as values
pivot_table3 = df_yearly_sum3.pivot(index='year', columns='property_type_en', values='actual_worth')

# Fill NaN values with 0 (optional)
# pivot_table['Hospitality'] = pivot_table['Hospitality']/1e6
# Display the pivot table
# pivot_table = pivot_table.drop('Residential/Commercial')
pivot_table3 = pivot_table3.reset_index()
pivot_table3
# Out:
# property_type_en  year      Building          Land          Unit         Villa
# 0                 2012  4.010846e+10  7.316902e+10  4.489636e+10  2.868328e+10
# 1                 2013  5.169689e+10  7.758636e+10  8.443911e+10  5.257498e+10
# 2                 2014  7.318195e+10  5.263864e+10  7.883106e+10  4.889284e+10
# 3                 2015  9.354936e+10  6.029337e+10  5.919266e+10  4.803962e+10
# 4                 2016  8.121566e+10  8.783826e+10  5.455021e+10  4.128305e+10
# 5                 2017  8.956237e+10  7.622280e+10  6.083750e+10  4.257555e+10
# 6                 2018  6.688233e+10  7.417936e+10  4.534411e+10  3.008190e+10
# 7                 2019  5.471271e+10  7.375944e+10  5.497026e+10  3.089526e+10
# 8                 2020  5.317935e+10  4.451376e+10  3.914106e+10  3.376072e+10
# 9                 2021  5.397630e+10  9.657581e+10  8.294272e+10  6.015764e+10
# 10                2022  5.485939e+10  2.437928e+11  1.543483e+11  6.719988e+10
# 11                2023  5.328553e+10  2.540219e+11  2.323459e+11  9.411803e+10

# %%
import matplotlib.pyplot as plt

# Convert actual_worth values to billions
pivot_table3.iloc[:, 1:] = pivot_table3.iloc[:, 1:].div(1e9)

# Plot stacked bar graph
plt.figure(figsize=(12, 8))
ax = pivot_table3.set_index('year').plot(kind='bar', stacked=True, color=['#2c3e50', '#8e44ad', '#c0392b', '#d35400'], figsize=(12, 8))

# Customize plot
plt.title('Yearly Breakdown by Property Type (in Billions)')
plt.xlabel('Year')
plt.ylabel('Value (in Billions)')
plt.legend(title='Property Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Add labels on each bar
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center', fontsize=10)

# Show plot
plt.show()

# %%
df
# Out:
#            transaction_id  procedure_id  trans_group_id trans_group_en  \
# 170904    1-110-2011-2950           110               1          Sales
# 553155    1-11-2011-20165            11               1          Sales
# 508222       1-11-2012-11            11               1          Sales
# 1082260   1-11-2011-20872            11               1          Sales
# 361112       2-13-2012-11            13               2      Mortgages
# ...                   ...           ...             ...            ...
# 90721    1-102-2023-69390           102               1          Sales
# 538905   1-102-2023-68620           102               1          Sales
# 206331   1-102-2023-68629           102               1          Sales
# 499478   1-102-2023-69433           102               1          Sales
# 1011835  1-102-2023-69439           102               1          Sales
#
#                  procedure_name_en instance_date  property_type_id  \
# 170904   Lease to Own Registration    2012-01-02                 1
# 553155                        Sell    2012-01-02                 3
# 508222                        Sell    2012-01-02                 4
# 1082260                       Sell    2012-01-02                 3
# 361112       Mortgage Registration    2012-01-02                 3
# ...                            ...           ...               ...
# 90721      Sell - Pre registration    2023-12-29                 3
# 538905     Sell - Pre registration    2023-12-29                 3
# 206331     Sell - Pre registration    2023-12-29                 3
# 499478     Sell - Pre registration    2023-12-29                 3
# 1011835    Sell - Pre registration    2023-12-29                 3
#
#         property_type_en  property_sub_type_id property_sub_type_en  ...  \
# 170904              Land                   NaN                  NaN  ...
# 553155              Unit                  60.0                 Flat  ...
# 508222             Villa                   NaN                  NaN  ...
# 1082260             Unit                  60.0                 Flat  ...
# 361112              Unit                  60.0                 Flat  ...
# ...                  ...                   ...                  ...  ...
# 90721               Unit                  60.0                 Flat  ...
# 538905              Unit                  60.0                 Flat  ...
# 206331              Unit                  60.0                 Flat  ...
# 499478              Unit                  60.0                 Flat  ...
# 1011835             Unit                  60.0                 Flat  ...
#
#         has_parking  procedure_area actual_worth  meter_sale_price rent_value  \
# 170904            0          540.14    3264800.0           6044.36        NaN
# 553155            1           93.09    1462425.0          15709.80        NaN
# 508222            0          929.03    1700000.0           1829.87        NaN
# 1082260           1           94.05     616565.0           6555.72        NaN
# 361112            1          153.01     700000.0           4574.86        NaN
# ...             ...             ...          ...               ...        ...
# 90721             1          109.93    2780799.0          25296.09        NaN
# 538905            1          376.05    6770400.0          18003.99        NaN
# 206331            1          174.02    3176067.0          18251.17        NaN
# 499478            1           37.84     640570.0          16928.38        NaN
# 1011835           1           67.75    1613888.0          23821.23        NaN
#
#         meter_rent_price  no_of_parties_role_1 no_of_parties_role_2  \
# 170904               NaN                   2.0                  2.0
# 553155               NaN                   1.0                  1.0
# 508222               NaN                  14.0                  2.0
# 1082260              NaN                   1.0                  1.0
# 361112               NaN                   1.0                  1.0
# ...                  ...                   ...                  ...
# 90721                NaN                   1.0                  1.0
# 538905               NaN                   1.0                  1.0
# 206331               NaN                   1.0                  1.0
# 499478               NaN                   1.0                  1.0
# 1011835              NaN                   1.0                  1.0
#
#         no_of_parties_role_3  year
# 170904                   2.0  2012
# 553155                   0.0  2012
# 508222                   0.0  2012
# 1082260                  0.0  2012
# 361112                   0.0  2012
# ...                      ...   ...
# 90721                    0.0  2023
# 538905                   0.0  2023
# 206331                   0.0  2023
# 499478                   0.0  2023
# 1011835                  0.0  2023
#
# [899613 rows x 33 columns]

# %%
# Convert 'instance_date' to datetime format
df['instance_date'] = pd.to_datetime(df['instance_date'])

# Extract year from 'instance_date'
df['year'] = df['instance_date'].dt.year

# Group by 'year' and 'property_usage_en', then sum 'actual_worth'
df_yearly_sum4 = df.groupby(['year', 'trans_group_en'])['actual_worth'].sum().reset_index()

# Create pivot table with 'year' as index, 'property_usage_en' as columns, and sum of 'actual_worth' as values
pivot_table4 = df_yearly_sum4.pivot(index='year', columns='trans_group_en', values='actual_worth')

# Fill NaN values with 0 (optional)
# pivot_table['Hospitality'] = pivot_table['Hospitality']/1e6
# Display the pivot table
# pivot_table = pivot_table.drop('Residential/Commercial')
pivot_table4 = pivot_table4.reset_index()
pivot_table4
# Out:
# trans_group_en  year         Gifts     Mortgages         Sales
# 0               2012  3.729388e+09  1.097947e+11  7.333304e+10
# 1               2013  5.411036e+09  1.136525e+11  1.472338e+11
# 2               2014  6.644342e+09  1.064393e+11  1.404608e+11
# 3               2015  1.579247e+10  1.252194e+11  1.200631e+11
# 4               2016  1.894129e+10  1.365035e+11  1.094423e+11
# 5               2017  2.498605e+10  1.281078e+11  1.161044e+11
# 6               2018  2.322783e+10  1.184219e+11  7.483796e+10
# 7               2019  1.863918e+10  1.193197e+11  7.637883e+10
# 8               2020  1.475044e+10  8.591815e+10  6.992630e+10
# 9               2021  1.605856e+10  1.286331e+11  1.489608e+11
# 10              2022  2.996905e+10  2.265987e+11  2.636326e+11
# 11              2023  3.224868e+10  1.899182e+11  4.116044e+11

# %%
# Convert actual_worth values to billions
pivot_table4.iloc[:, 1:] = pivot_table4.iloc[:, 1:].div(1e9)

# Plot stacked bar graph
plt.figure(figsize=(12, 8))
ax = pivot_table4.set_index('year').plot(kind='bar', stacked=True, color=['#2c3e50', '#8e44ad', '#c0392b'], figsize=(12, 8))

# Customize plot
plt.title('Yearly Breakdown by Property Type (in Billions)')
plt.xlabel('Year')
plt.ylabel('Value (in Billions)')
plt.legend(title='Property Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Add labels on each bar
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='center', fontsize=10)

# Show plot
plt.show()

# %%
df
# Out:
#            transaction_id  procedure_id  trans_group_id trans_group_en  \
# 170904    1-110-2011-2950           110               1          Sales
# 553155    1-11-2011-20165            11               1          Sales
# 508222       1-11-2012-11            11               1          Sales
# 1082260   1-11-2011-20872            11               1          Sales
# 361112       2-13-2012-11            13               2      Mortgages
# ...                   ...           ...             ...            ...
# 90721    1-102-2023-69390           102               1          Sales
# 538905   1-102-2023-68620           102               1          Sales
# 206331   1-102-2023-68629           102               1          Sales
# 499478   1-102-2023-69433           102               1          Sales
# 1011835  1-102-2023-69439           102               1          Sales
#
#                  procedure_name_en instance_date  property_type_id  \
# 170904   Lease to Own Registration    2012-01-02                 1
# 553155                        Sell    2012-01-02                 3
# 508222                        Sell    2012-01-02                 4
# 1082260                       Sell    2012-01-02                 3
# 361112       Mortgage Registration    2012-01-02                 3
# ...                            ...           ...               ...
# 90721      Sell - Pre registration    2023-12-29                 3
# 538905     Sell - Pre registration    2023-12-29                 3
# 206331     Sell - Pre registration    2023-12-29                 3
# 499478     Sell - Pre registration    2023-12-29                 3
# 1011835    Sell - Pre registration    2023-12-29                 3
#
#         property_type_en  property_sub_type_id property_sub_type_en  ...  \
# 170904              Land                   NaN                  NaN  ...
# 553155              Unit                  60.0                 Flat  ...
# 508222             Villa                   NaN                  NaN  ...
# 1082260             Unit                  60.0                 Flat  ...
# 361112              Unit                  60.0                 Flat  ...
# ...                  ...                   ...                  ...  ...
# 90721               Unit                  60.0                 Flat  ...
# 538905              Unit                  60.0                 Flat  ...
# 206331              Unit                  60.0                 Flat  ...
# 499478              Unit                  60.0                 Flat  ...
# 1011835             Unit                  60.0                 Flat  ...
#
#         has_parking  procedure_area actual_worth  meter_sale_price rent_value  \
# 170904            0          540.14    3264800.0           6044.36        NaN
# 553155            1           93.09    1462425.0          15709.80        NaN
# 508222            0          929.03    1700000.0           1829.87        NaN
# 1082260           1           94.05     616565.0           6555.72        NaN
# 361112            1          153.01     700000.0           4574.86        NaN
# ...             ...             ...          ...               ...        ...
# 90721             1          109.93    2780799.0          25296.09        NaN
# 538905            1          376.05    6770400.0          18003.99        NaN
# 206331            1          174.02    3176067.0          18251.17        NaN
# 499478            1           37.84     640570.0          16928.38        NaN
# 1011835           1           67.75    1613888.0          23821.23        NaN
#
#         meter_rent_price  no_of_parties_role_1 no_of_parties_role_2  \
# 170904               NaN                   2.0                  2.0
# 553155               NaN                   1.0                  1.0
# 508222               NaN                  14.0                  2.0
# 1082260              NaN                   1.0                  1.0
# 361112               NaN                   1.0                  1.0
# ...                  ...                   ...                  ...
# 90721                NaN                   1.0                  1.0
# 538905               NaN                   1.0                  1.0
# 206331               NaN                   1.0                  1.0
# 499478               NaN                   1.0                  1.0
# 1011835              NaN                   1.0                  1.0
#
#         no_of_parties_role_3  year
# 170904                   2.0  2012
# 553155                   0.0  2012
# 508222                   0.0  2012
# 1082260                  0.0  2012
# 361112                   0.0  2012
# ...                      ...   ...
# 90721                    0.0  2023
# 538905                   0.0  2023
# 206331                   0.0  2023
# 499478                   0.0  2023
# 1011835                  0.0  2023
#
# [899613 rows x 33 columns]

# %%
# Convert 'instance_date' to datetime format
df['instance_date'] = pd.to_datetime(df['instance_date'])

# Extract year from 'instance_date'
df['year'] = df['instance_date'].dt.year

# Group by 'year' and 'property_usage_en', then sum 'actual_worth'
df_yearly_sum5 = df.groupby(['year', 'area_name_en'])['actual_worth'].sum().reset_index()

# Create pivot table with 'year' as index, 'property_usage_en' as columns, and sum of 'actual_worth' as values
pivot_table5 = df_yearly_sum5.pivot(index='year', columns='area_name_en', values='actual_worth')

# Fill NaN values with 0 (optional)
# pivot_table['Hospitality'] = pivot_table['Hospitality']/1e6
# Display the pivot table
# pivot_table = pivot_table.drop('Residential/Commercial')
pivot_table5 = pivot_table5.reset_index()
pivot_table5.columns
# Out:
# Index(['year', 'Abu Hail', 'Al Aweer First', 'Al Aweer Second', 'Al Bada',
#        'Al Baraha', 'Al Barsha First', 'Al Barsha Second',
#        'Al Barsha South Fifth', 'Al Barsha South Fourth',
#        ...
#        'Wadi Al Safa 3', 'Wadi Al Safa 4', 'Wadi Al Safa 5', 'Wadi Al Safa 6',
#        'Wadi Al Safa 7', 'Wadi Alshabak', 'Warsan Fourth', 'World Islands',
#        'Zaabeel First', 'Zaabeel Second'],
#       dtype='object', name='area_name_en', length=207)

# %%
# pivot_table2.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 pivot_table2.columns
#
# NameError: name 'pivot_table2' is not defined

# %%
# Plotting the data
# plt.figure(figsize=(12, 8))

# # Plot each factor as a line on the chart
# for column in pivot_table2.columns[1:]:  # Exclude the 'Year' column
#     plt.plot(pivot_table2['Year'], pivot_table2[column], marker='o', label=column)

# # Adding labels and title
# plt.xlabel('Year')
# plt.ylabel('Values')
# plt.title('Yearly Trends of Various Economic Factors')
# plt.legend()

# # Display the plot
# plt.grid(True)
# plt.show()

# %%
df

# %%
original_data = {
    'Countries': ['USA', 'China', 'Japan', 'Germany', 'UK', 'France', 'Canada', 'Australia', 'South Korea', 'India'],
    'Volume': [59.63, 34.8, 14.11, 11.82, 10.7, 6.56, 5.85, 4.85, 4.89, 4.08],
    'F_countries': ['Turkey', 'UAE', 'Israel', 'Iceland', 'Russia', 'Hungary', 'Singapore', 'Japan', 'Portugal', 'Slovenia'],
    'V_volumes': [59.63, 34.8, 14.11, 11.82, 10.7, 6.56, 5.85, 4.85, 4.89, 4.08]
}
original_data = pd.DataFrame(original_data)
csv_file_path = 'World_Market_Volume.csv'
original_data.to_csv(csv_file_path, index=False)

# %%
# largest market


import matplotlib.pyplot as plt
import numpy as np

# Data
countries = ['USA', 'China', 'Japan', 'Germany', 'UK', 'France', 'Canada', 'Australia', 'South Korea', 'India']
values = [132, 55, 24, 20, 15, 12, 10, 9, 8, 7]  # Values in trillions

# Convert values to trillions with two decimal places
values_trillions = [f"${v:.2f}T" for v in values]

# Generate colors for each slice
colors = plt.cm.Paired(range(len(countries)))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(14, 10))

# Plot the pie chart with a thicker ring
wedges, texts, autotexts = ax.pie(values, colors=colors, startangle=140, 
                                  wedgeprops=dict(width=0.45),  # Increased thickness by 50%
                                  autopct='%1.2fT',  # Show values inside the rings
                                  pctdistance=0.85)  # Position labels inside the ring

# Update autopct text colors to match segment colors
for autotext, color in zip(autotexts, colors):
    autotext.set_color('white')  # Text color inside the ring

# Create a table on the left side with matching colors
table_data = list(zip(countries, values_trillions))
table = plt.table(cellText=table_data, colLabels=['Country', 'Value (Trillions)'],
                  cellLoc='center', loc='left', bbox=[-0.3, 0, 0.3, 1], colColours=['#f5f5f5', '#f5f5f5'])

# Set table font size and color
table.auto_set_font_size(False)
table.set_fontsize(8)  # Reduce font size
for i, key in enumerate(table._cells.keys()):
    cell = table._cells[key]
    cell.set_edgecolor('black')
    if i % len(countries) == 0:  # Color header cells
        cell.set_facecolor('#f5f5f5')
    else:
        cell.set_facecolor(colors[i // len(countries)])
    cell.set_text_props(color='black')

# Add a title
plt.title('Global Real Estate Giants : The Top 10 Markets by Value', pad=20, fontsize=14)

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = {
    'Country': ['Turkey', 'UAE', 'Israel', 'Iceland', 'Russia', 'Hungary', 'Singapore', 'Japan', 'Portugal', 'Slovenia'],
    'Growth Rate(T)': [59.63, 34.8, 14.11, 11.82, 10.7, 6.56, 5.85, 4.85, 4.89, 4.08]
}
df = pd.DataFrame(data)

# Define a list of colors for each bar
colors = plt.cm.Paired(range(len(df)))

# Plotting
plt.figure(figsize=(12, 6))
bars = plt.barh(df['Country'], df['Growth Rate(T)'], color=colors)

# Adding annotations
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{bar.get_width()} Trillion $', va='center', ha='left', fontsize=10, color='black')

plt.xlabel('Growth Rate (Trillion $)')
plt.title('Top 10 Fastest Growing Real Estate Markets - 2023')
plt.gca().invert_yaxis()  # Invert y-axis to have the largest value on top

# Ensure no grid lines are shown
plt.grid(False)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Define the data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 
             2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 
             2020, 2021, 2022, 2023],
    'Gross Domestic Product': [10.85, 1.40, 2.43, 8.80, 9.57, 4.86, 9.84, 3.18, 3.19, -5.24, 
                                1.60, 6.22, 1.82, 5.06, 4.17, 6.79, 5.56, 0.74, 1.31, 1.11, 
                                -4.96, 4.35, 7.85, 3.40],
    'Inflation Rate': [8.38, 6.56, 4.74, 2.92, 1.10, -0.72, -2.54, -4.36, 12.25, 1.56, 
                       0.88, 0.88, 0.66, 1.10, 2.35, 4.07, 1.62, 1.97, 3.07, -1.93, 
                       -2.08, -0.01, 4.83, 6.50],
    'Population Growth Rate': [5.6, 5.3, 5.1, 4.8, 4.6, 7, 13.5, 18.1, 17.4, 13.4, 
                                5.9, 1.1, 1, 1, 1, 0.9, 0.9, 0.8, 0.8, 0.8, 
                                0.8, 0.8, 0.8, 0.8],
    'Infrastructure Development Rate': [80, 81, 81, 82, 82, 83, 83, 83, 83, 84, 
                                         84, 84, 85, 85, 85, 86, 86, 87, 87, 87, 
                                         87, 88, 88, 88],
    'Energy Use Per Capita': [9624, 11639, 10974, 10287, 10481, 10394, 9430, 8538, 8488, 7501, 
                               7273, 7503, 7893, 7992, 7976, 7906, 7837, 7628, 7559, 7489, 
                               7420, 7350, 7325, 7285],
    'Global Economic Growth Rate': [9.8, 9, 8.6, 8.6, 9.5, 9.6, 10.7, 10.8, 9.4, 7.5, 
                                     9.3, 9.5, 9.9, 10, 10.4, 10.5, 10.1, 10.8, 10.6, 10.3, 
                                     9.3, 9.6, 8.3, 7.8],
    'Gross National Income': [0, 0, -1.4, 7.9, 10.1, 6.1, 10.6, 4.5, 1, -5.6, 
                               0.5, 6.3, 1.9, 5.1, 4.2, 7.1, 5.6, 0.9, 0.8, 1.3, 
                               -5.9, 2.3, 3.2, 3.1],
    'Unemployment Rate': [2.3, 2.4, 2.7, 2.9, 3, 3.1, 3, 2.9, 2.8, 2.9, 
                          2.8, 2.6, 2.3, 2.1, 2, 1.8, 1.6, 2.5, 2.2, 2.3, 
                          4.3, 3.1, 2.9, 2.7],
    'Foreign Direct Investment': [-0.5, 1.1, 0.1, 3.4, 6.8, 6, 5.8, 5.5, 1.6, 0.4, 
                                  2.9, 2, 2.5, 2.4, 2.7, 2.3, 2.6, 2.7, 2.4, 4.3, 
                                  5.7, 5, 4.5, 6.8]
}

# Create the DataFrame
df = pd.DataFrame(data)
df['Year'] = df['Year'].astype(int)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 
             2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 
             2020, 2021, 2022, 2023],
    'Gross Domestic Product': [10.85, 1.40, 2.43, 8.80, 9.57, 4.86, 9.84, 3.18, 3.19, -5.24, 
                                1.60, 6.22, 1.82, 5.06, 4.17, 6.79, 5.56, 0.74, 1.31, 1.11, 
                                -4.96, 4.35, 7.85, 3.40],
    'Inflation Rate': [8.38, 6.56, 4.74, 2.92, 1.10, -0.72, -2.54, -4.36, 12.25, 1.56, 
                       0.88, 0.88, 0.66, 1.10, 2.35, 4.07, 1.62, 1.97, 3.07, -1.93, 
                       -2.08, -0.01, 4.83, 6.50],
    'Population Growth Rate': [5.6, 5.3, 5.1, 4.8, 4.6, 7, 13.5, 18.1, 17.4, 13.4, 
                                5.9, 1.1, 1, 1, 1, 0.9, 0.9, 0.8, 0.8, 0.8, 
                                0.8, 0.8, 0.8, 0.8],
    'Infrastructure Development Rate': [80, 81, 81, 82, 82, 83, 83, 83, 83, 84, 
                                         84, 84, 85, 85, 85, 86, 86, 87, 87, 87, 
                                         87, 88, 88, 88],
    'Energy Use Per Capita': [9624, 11639, 10974, 10287, 10481, 10394, 9430, 8538, 8488, 7501, 
                               7273, 7503, 7893, 7992, 7976, 7906, 7837, 7628, 7559, 7489, 
                               7420, 7350, 7325, 7285],
    'Global Economic Growth Rate': [9.8, 9, 8.6, 8.6, 9.5, 9.6, 10.7, 10.8, 9.4, 7.5, 
                                     9.3, 9.5, 9.9, 10, 10.4, 10.5, 10.1, 10.8, 10.6, 10.3, 
                                     9.3, 9.6, 8.3, 7.8],
    'Gross National Income': [0, 0, -1.4, 7.9, 10.1, 6.1, 10.6, 4.5, 1, -5.6, 
                               0.5, 6.3, 1.9, 5.1, 4.2, 7.1, 5.6, 0.9, 0.8, 1.3, 
                               -5.9, 2.3, 3.2, 3.1],
    'Unemployment Rate': [2.3, 2.4, 2.7, 2.9, 3, 3.1, 3, 2.9, 2.8, 2.9, 
                          2.8, 2.6, 2.3, 2.1, 2, 1.8, 1.6, 2.5, 2.2, 2.3, 
                          4.3, 3.1, 2.9, 2.7],
    'Foreign Direct Investment': [-0.5, 1.1, 0.1, 3.4, 6.8, 6, 5.8, 5.5, 1.6, 0.4, 
                                  2.9, 2, 2.5, 2.4, 2.7, 2.3, 2.6, 2.7, 2.4, 4.3, 
                                  5.7, 5, 4.5, 6.8]
}

# Create the DataFrame
df = pd.DataFrame(data)


# Plotting Line Chart
plt.figure(figsize=(14, 6))
plt.plot(df['Year'], df['Gross Domestic Product'], label='GDP', color='tab:blue', marker='o')
plt.plot(df['Year'], df['Inflation Rate'], label='Inflation Rate', color='tab:orange', marker='o')
plt.plot(df['Year'], df['Global Economic Growth Rate'], label='Global Economic Growth Rate', color='tab:green', marker='o')

# Adding labels for each data point
for i, txt in enumerate(df['Gross Domestic Product']):
    plt.annotate(f'{txt:.2f}', (df['Year'][i], df['Gross Domestic Product'][i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)
for i, txt in enumerate(df['Inflation Rate']):
    plt.annotate(f'{txt:.2f}', (df['Year'][i], df['Inflation Rate'][i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)
for i, txt in enumerate(df['Global Economic Growth Rate']):
    plt.annotate(f'{txt:.2f}', (df['Year'][i], df['Global Economic Growth Rate'][i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

plt.xlabel('Year')
plt.ylabel('Rate(%)')
plt.title('Trends Over the Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the data for 10 specific years
data = {
    'Year': [2000, 2005, 2010, 2015, 2020, 2001, 2006, 2011, 2016, 2021],
    'Population Growth Rate': [5.6, 7.0, 5.9, 0.9, 0.8, 5.3, 13.5, 1.1, 0.9, 0.8],
    'Infrastructure Development Rate': [80, 83, 84, 86, 87, 81, 83, 84, 86, 87]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Multiply Population Growth Rate by 10 for comparison
df['Population Growth Rate (x10)'] = df['Population Growth Rate'] * 10

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Set bar width
bar_width = 0.35
index = np.arange(len(df['Year']))

# Plot the bars
bars_population = ax1.bar(index - bar_width / 2, df['Population Growth Rate (x10)'], bar_width, color='skyblue', label='Population Growth Rate (x10)')
bars_infrastructure = ax1.bar(index + bar_width / 2, df['Infrastructure Development Rate'], bar_width, color='darkblue', label='Infrastructure Development Rate')

# Add labels to each bar
def add_labels(bars, is_percentage=False):
    for bar in bars:
        height = bar.get_height()
        label = f'{height:.1f}'
        ax1.text(
            bar.get_x() + bar.get_width() / 2,
            height + 1,
            label,
            ha='center',
            va='bottom',
            fontsize=10,
            color='black'
        )

add_labels(bars_population)
add_labels(bars_infrastructure)

# Set labels, title, and legend
ax1.set_xlabel('Year')
ax1.set_ylabel('Values')
ax1.set_title('Population Growth Rate vs Infrastructure Development Rate')
ax1.set_xticks(index)
ax1.set_xticklabels(df['Year'], rotation=45)
ax1.legend(loc='upper left')

# Display the chart
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'Year': [2000, 2005, 2010, 2015, 2020, 2001, 2006, 2011, 2016, 2021],
    'Gross Domestic Product': [10.85, 4.86, 1.60, 6.22, 4.35, 1.40, 9.84, 6.22, 5.56, 4.35],
    'Inflation Rate': [8.38, -0.72, 0.88, 0.66, -0.01, 6.56, -2.54, 0.88, 1.62, -0.01],
    'Population Growth Rate': [5.6, 7.0, 5.9, 0.9, 0.8, 5.3, 13.5, 1.1, 0.9, 0.8],
    'Infrastructure Development Rate': [80, 83, 84, 86, 87, 81, 83, 84, 86, 87],
    'Energy Use Per Capita': [9624, 10394, 7273, 7503, 7350, 11639, 9430, 7503, 7837, 7350],
    'Global Economic Growth Rate': [9.8, 9.6, 9.3, 9.5, 9.6, 9.0, 10.7, 9.5, 10.1, 9.6],
    'Gross National Income': [0, 6.1, 0.5, 6.3, 2.3, 0, 10.6, 6.3, 5.6, 2.3],
    'Unemployment Rate': [2.3, 3.1, 2.8, 2.6, 3.1, 2.4, 3.0, 2.6, 1.6, 3.1],
    'Foreign Direct Investment': [-0.5, 6, 2.9, 2.5, 5.7, 1.1, 5.8, 2.5, 2.6, 5]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Drop the 'Year' column as it's not part of the correlation analysis
df_corr = df.drop(columns='Year')

# Calculate the correlation matrix
corr_matrix = df_corr.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1, center=0,
                      linewidths=0.5, linecolor='black', annot_kws={'size': 10, 'weight': 'bold', 'color': 'black'})

# Set the title
plt.title('Correlation Heatmap Between Economic Factors', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()
